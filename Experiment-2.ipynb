# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder, StandardScaler

# %%
df = pd.read_csv('titanic.csv')
print("Initial Data:")
print(df.head())
print("\nMissing Values:\n", df.isnull().sum())
# Out:
# Initial Data:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S
#
# Missing Values:
#  PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          327
# Embarked         0
# dtype: int64

# %%
# Fill missing Age with mean
df['Age'] = df['Age'].fillna(df['Age'].mean())

# Drop rows with missing 'Embarked'
df = df.dropna(subset=['Embarked'])

# Fill missing Cabin with 'Unknown'
df['Cabin'] = df['Cabin'].fillna('Unknown')

print("\nAfter Handling Missing Values:\n", df.isnull().sum())
# Out:
# After Handling Missing Values:
#  PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %%
initial_shape = df.shape
df.drop_duplicates(inplace=True)
print(f"\nDuplicates removed: {initial_shape[0] - df.shape[0]}")
# Out:
# Duplicates removed: 0

# %%
# Encode 'Sex' column
le = LabelEncoder()
df['Sex'] = le.fit_transform(df['Sex'])
# One-hot encode 'Embarked' column
df = pd.get_dummies(df, columns=['Embarked'])
# Optional: drop columns not used in modeling
df.drop(['Name', 'Ticket', 'Cabin'], axis=1, inplace=True)

# %%
scaler = StandardScaler()
df[['Age', 'Fare']] = scaler.fit_transform(df[['Age', 'Fare']])

# %%
print("\nCleaned Data Preview:")
print(df.head())
print("\nData Info:")
print(df.info())
print("\nStatistical Summary:")
print(df.describe())
# Out:
# Cleaned Data Preview:
#    PassengerId  Survived  Pclass  Sex       Age  SibSp  Parch      Fare  \
# 0          892         0       3    1  0.298549      0      0 -0.497641
# 1          893         1       3    0  1.181328      1      0 -0.512507
# 2          894         0       2    1  2.240662      0      0 -0.464326
# 3          895         0       3    1 -0.231118      0      0 -0.482702
# 4          896         1       3    0 -0.584229      1      1 -0.417714
#
#    Embarked_C  Embarked_Q  Embarked_S
# 0       False        True       False
# 1       False       False        True
# 2       False        True       False
# 3       False       False        True
# 4       False       False        True
#
# Data Info:
# <class 'pandas.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Survived     418 non-null    int64
#  2   Pclass       418 non-null    int64
#  3   Sex          418 non-null    int64
#  4   Age          332 non-null    float64
#  5   SibSp        418 non-null    int64
#  6   Parch        418 non-null    int64
#  7   Fare         418 non-null    float64
#  8   Embarked_C   418 non-null    bool
#  9   Embarked_Q   418 non-null    bool
#  10  Embarked_S   418 non-null    bool
# dtypes: bool(3), float64(2), int64(6)
# memory usage: 27.5 KB
# None
#
# Statistical Summary:
#        PassengerId    Survived      Pclass         Sex           Age  \
# count   418.000000  418.000000  418.000000  418.000000  3.320000e+02
# mean   1100.500000    0.363636    2.265550    0.636364  2.675236e-17
# std     120.810458    0.481622    0.841838    0.481622  1.001509e+00
# min     892.000000    0.000000    1.000000    0.000000 -2.125914e+00
# 25%     996.250000    0.000000    1.000000    0.000000 -6.548515e-01
# 50%    1100.500000    0.000000    3.000000    1.000000 -2.311178e-01
# 75%    1204.750000    1.000000    3.000000    1.000000  6.163496e-01
# max    1309.000000    1.000000    3.000000    1.000000  3.229374e+00
#
#             SibSp       Parch          Fare
# count  418.000000  418.000000  4.180000e+02
# mean     0.447368    0.392344  8.074349e-17
# std      0.896760    0.981429  1.001198e+00
# min      0.000000    0.000000 -6.380007e-01
# 25%      0.000000    0.000000 -4.964471e-01
# 50%      0.000000    0.000000 -3.788700e-01
# 75%      1.000000    0.000000 -7.378212e-02
# max      8.000000    9.000000  8.546887e+00
